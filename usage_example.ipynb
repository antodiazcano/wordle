# %%
from wordle import Wordle

# %%
W = Wordle()

# %%
W.play_game()
# Out:
# slate
#
# Have you won? 0
#
# Vector: 00211
# enact
#
# Have you won? 0
#
# Vector: 10202
# heart
#
# Have you won? 1
# Congratulations!
